# %% [markdown]
# ## Exploratory Data Analysis
# Remember the goal of EDA is to investigate the relationships between features and the
# relationship between the response variable and the features. Be thoughtful and creative
# about how to deepen your understanding of the data and inform the overall project goal
# with your findings.
#
#
#
# Things you may want to evaluate include:
#
# ● Is the response variable unbalanced?
#
# ● What is the distribution of each of the features?
#
# ● Are there features are correlated with a particular response value?
#
# ● Are there collinear features in the data?
#
# ● Are there outliers?
#
# ● What are the seasonal or linear trends?
#
# Ways to evaluate these include:
#
# ● Histograms or Distribution plots
#
# ● Histograms, Word Count- bigram, trigrams
#
# ● Scatter plots or Bi-plots
#
# ● Pearson correlation coefficients heat map
#
# ● Box plots
#
# ● Line plots
#
# Please note that the time estimates associated with this step of your capstone are
# approximated — you may take more or less time based on the complexity of your data.

# %%
# import all necesary packages and libraries

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
from nltk.sentiment.vader import SentimentIntensityAnalyzer
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\Quinn\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# load the dataset
df = pd.read_csv('sentimentdataset_cleaned.csv')

# %%
df.shape
# Out:
# (732, 14)

# %%
sns.pairplot(df, hue='Platform', palette = ["#000000","#C13584","#1877F2"]) # X, instagram, facebook respectively

# %%
plt.figure(figsize=(12,10))
print('Correlation between various features')
p=sns.heatmap(df.corr(), annot=True, cmap ='Blues')
# Out:
# Correlation between various features
# C:\Users\Quinn\AppData\Local\Temp\ipykernel_4424\643680619.py:3: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %%
# Identify numeric columns in the dataset
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

# Create histograms for each numeric feature
fig, axes = plt.subplots(nrows=len(numeric_columns)//2 + len(numeric_columns)%2, ncols=2, figsize=(14, len(numeric_columns)*2))
axes = axes.flatten()

for i, feature in enumerate(numeric_columns):
    sns.histplot(df[df[feature].notnull()][feature], kde=False, ax=axes[i])
    axes[i].set_title(f'Histogram of {feature}')
    axes[i].set_xlabel(feature)
    axes[i].set_ylabel('Frequency')

# Adjust layout
fig.tight_layout()
plt.show()

# %%
# histograms/distribution plots of every value
# Set the colors for each social media platform
colors = {"Twitter": "#000000", "Instagram": "#C13584", "Facebook": "#1877F2"}

# Define the numerical features to plot, ignore shares/
numerical_features = [ 'Sentiment_Score','Likes', 'Year', 'Month', 'Day', 'Hour' ]

# Create histograms for each numerical feature
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 12))
axes = axes.flatten()  # Flatten the axes array for easier iteration

for i, feature in enumerate(numerical_features):
    sns.histplot(data=df, x=feature, hue="Platform", palette=colors, element="step", ax=axes[i])
    axes[i].set_title(f'Distribution of {feature}', fontsize=14)
    axes[i].set_xlabel(feature, fontsize=12)
    axes[i].set_ylabel('Count', fontsize=12)

plt.tight_layout()
plt.show()

# %%
# Create distribution plots for each numerical feature
fig, axes = plt.subplots(nrows=3, ncols=2, figsize=(14, 12))
axes = axes.flatten()  # Flatten the axes array for easier iteration

for i, feature in enumerate(numerical_features):
    sns.kdeplot(data=df, x=feature, hue="Platform", palette=colors, ax=axes[i], common_norm=False)
    axes[i].set_title(f'Density Distribution of {feature}', fontsize=14)
    axes[i].set_xlabel(feature, fontsize=12)
    axes[i].set_ylabel('Density', fontsize=12)

plt.tight_layout()
plt.show()

# %%
#figure out which platforms are most popular in each of the top 10 countries in the dataset

# Determine the top 10 countries with the most entries
top_countries = df['Country'].value_counts().head(10).index.tolist()

# Filter the data for these top countries
filtered_data = df[df['Country'].isin(top_countries)]

# Create a countplot showing platform usage in the top 10 countries
plt.figure(figsize=(10, 6))
ax = sns.countplot(data=filtered_data, x='Country', hue='Platform', palette=colors)
ax.set_title('Social Media Platform Usage in Top 10 Countries', fontsize=16)
ax.set_xlabel('Country', fontsize=12)
ax.set_ylabel('Count', fontsize=12)
ax.legend(title='Platform')
plt.show()

# %%
# Filter the data for these top countries
filtered_data = df[df['Country'].isin(top_countries)]

sentiment_order = ['Positive', 'Neutral', 'Negative']
palette = {'Positive': 'green', 'Neutral': 'grey', 'Negative': 'red'}

# Create a countplot of sentiment distribution by country
plt.figure(figsize=(12, 8))
sns.countplot(data=filtered_data, x='Country', hue='Sentiment', palette=palette, hue_order=sentiment_order)
plt.title('Count of Sentiment by Country', fontsize=16)
plt.xlabel('Country', fontsize=12)
plt.ylabel('Count', fontsize=12)
plt.xticks(rotation=45)  # Rotate the country names for better visibility if necessary
plt.legend(title='Sentiment')
plt.show()

# %%
# Filter the data to include only the top 5 countries
top_5_countries = df['Country'].value_counts().head(5).index.tolist()

# Filter the data for these top countries
filtered_data = df[df['Country'].isin(top_5_countries)]

# Create a density plot for sentiment scores in the top 5 countries
plt.figure(figsize=(10, 6))
sns.kdeplot(data=filtered_data, x='Sentiment_Score', hue='Country', common_norm=False, palette='Set1')
plt.title('Distribution of Sentiment Scores by Top 5 Countries', fontsize=16)
plt.xlim(-1, 1)
plt.xlabel('Sentiment Score', fontsize=12)
plt.ylabel('Density', fontsize=12)
plt.show()

# %%
# Create a scatter plot of likes vs sentiment
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='Sentiment_Score', y='Likes', hue='Platform', palette=colors, alpha=0.6)
plt.title('Scatter Plot of Likes vs Sentiment Score', fontsize=16)
plt.xlabel('Sentiment Score', fontsize=12)
plt.ylabel('Likes', fontsize=12)
plt.grid(True)
plt.show()

# %%
#Create a scatter plots sentiment vs month 
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, y='Sentiment_Score', x='Month', hue='Platform', palette=colors, alpha=0.6)
plt.title('Scatter Plot of Sentiment Score vs Month', fontsize=16)
plt.ylabel('Sentiment Score', fontsize=12)
plt.xlabel('Month', fontsize=12)
plt.grid(True)
plt.show()

# %%
# Create a scatter plot for sentiment Score vs hour
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, y='Sentiment_Score', x='Hour', hue='Platform', palette=colors, alpha=0.6)
plt.title('Scatter Plot of Sentiment Score vs. Hours of the Hours of the Dat', fontsize=16)
plt.ylabel('Sentiment Score', fontsize=12)
plt.xlabel('Hour', fontsize=12)
plt.grid(True)
plt.show()

# %%
# Create a scatter plot for Likes vs Sentiment Score
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, y='Sentiment_Score', x='Year', hue='Platform', palette=colors, alpha=0.6)
plt.title('Scatter Plot of Sentiment Score vs Year', fontsize=16)
plt.xlabel('Year', fontsize=12)
plt.ylabel('Sentiment Score', fontsize=12)
plt.grid(True)
plt.show()

# %%
df.head()
# Out:
#                                                 Text Sentiment  \
# 0   enjoying a beautiful day at the park nature park  Positive
# 1  traffic was terrible this morning traffic morning   Neutral
# 2  just finished an amazing workout  fitness workout  Positive
# 3  excited about the upcoming weekend getaway tra...   Neutral
# 4  trying out a new recipe for dinner tonight coo...   Neutral
#
#              Timestamp        User   Platform  Retweets  Likes    Country  \
# 0  2023-01-15 12:30:00     User123    Twitter      15.0   30.0        USA
# 1  2023-01-15 08:45:00   CommuterX    Twitter       5.0   10.0     Canada
# 2  2023-01-15 15:45:00  FitnessFan  Instagram      20.0   40.0        USA
# 3  2023-01-15 18:20:00  AdventureX   Facebook       8.0   15.0         UK
# 4  2023-01-15 19:55:00    ChefCook  Instagram      12.0   25.0  Australia
#
#    Year  Month  Day  Hour                               Processed_Text  \
# 0  2023      1   15    12             enjoy beauti day park natur park
# 1  2023      1   15     8            traffic terribl morn traffic morn
# 2  2023      1   15    15              finish amaz workout fit workout
# 3  2023      1   15    18  excit upcom weekend getaway travel adventur
# 4  2023      1   15    19       tri new recip dinner tonight cook food
#
#    Sentiment_Score
# 0           0.4939
# 1           0.0000
# 2           0.3612
# 3           0.0000
# 4           0.0000

# %%
# Create a new column for the day of the week
df['Day_of_Week'] = pd.to_datetime(df['Timestamp'], errors='coerce').dt.day_name()

# Calculate the mean and standard error of the sentiment scores grouped by day of the week
weekly_sentiment = df.groupby('Day_of_Week')['Sentiment_Score'].agg(['mean', 'sem']).reset_index()

# Sorting by day of the week for proper sequential plotting
day_order = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday", "Saturday", "Sunday"]
weekly_sentiment['Day_of_Week'] = pd.Categorical(weekly_sentiment['Day_of_Week'], categories=day_order, ordered=True)
weekly_sentiment = weekly_sentiment.sort_values('Day_of_Week')

# Create the plot
plt.figure(figsize=(10, 6))
plt.errorbar(x=weekly_sentiment['Day_of_Week'], y=weekly_sentiment['mean'], yerr=weekly_sentiment['sem'], fmt='-o', capsize=5)
plt.title('Weekly Sentiment Score with Error Bars')
plt.xlabel('Day of the Week')
plt.ylabel('Average Sentiment Score')
plt.ylim(-1,1)
plt.grid(True)
plt.show()

# %%
#Create a line plot sentiment vs day of the month 
monthly_sentiment = df.groupby('Day')['Sentiment_Score'].agg(['mean', 'sem']).reset_index()

# Create the plot
plt.figure(figsize=(10, 6))
plt.errorbar(x=monthly_sentiment['Day'], y=monthly_sentiment['mean'], yerr=monthly_sentiment['sem'], fmt='-o', capsize=5)
plt.title('Daily Sentiment Score with Error Bars')
plt.xlabel('Day of the Month')
plt.ylabel('Average Sentiment Score')
plt.ylim(-1,1)
plt.grid(True)
plt.show()

# %%
#Create a line plot sentiment vs month 
monthly_sentiment = df.groupby('Month')['Sentiment_Score'].agg(['mean', 'sem']).reset_index()

# Create the plot
plt.figure(figsize=(10, 6))
plt.errorbar(x=monthly_sentiment['Month'], y=monthly_sentiment['mean'], yerr=monthly_sentiment['sem'], fmt='-o', capsize=5)
plt.title('Monthly Sentiment Score with Error Bars')
plt.xlabel('Month')
plt.ylabel('Average Sentiment Score')
plt.ylim(-1,1)
plt.xticks(range(1, 13))  #months are numbered from 1 to 12
plt.grid(True)
plt.show()

# %%
#Create a line plot sentiment vs month 
yearly_sentiment = df.groupby('Year')['Sentiment_Score'].agg(['mean', 'sem']).reset_index()

# Create the plot
plt.figure(figsize=(10, 6))
plt.errorbar(x=yearly_sentiment['Year'], y=yearly_sentiment['mean'], yerr=yearly_sentiment['sem'], fmt='-o', capsize=5)
plt.title('Yearly Sentiment Score with Error Bars')
plt.xlabel('Year')
plt.ylim(-1,1)
plt.ylabel('Average Sentiment Score')
plt.grid(True)
plt.show()

# %%
# most common words
# Function to process text and return most common words
df['common_word_list'] = df['Processed_Text'].apply(lambda x: str(x).split())
top_words = Counter([item for sublist in df['temp_list'] for item in sublist])
top_words_df = pd.DataFrame(top_words.most_common(20), columns=['Common_Words', 'Count'])

top_words_df.style.background_gradient(cmap='Blues')
# Out:
# <style type="text/css">
# #T_fb689_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fb689_row1_col1 {
#   background-color: #1e6db2;
#   color: #f1f1f1;
# }
# #T_fb689_row2_col1, #T_fb689_row3_col1, #T_fb689_row4_col1 {
#   background-color: #3c8cc3;
#   color: #f1f1f1;
# }
# #T_fb689_row5_col1 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_fb689_row6_col1, #T_fb689_row7_col1 {
#   background-color: #c9ddf0;
#   color: #000000;
# }
# #T_fb689_row8_col1, #T_fb689_row9_col1, #T_fb689_row10_col1 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_fb689_row11_col1, #T_fb689_row12_col1 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_fb689_row13_col1, #T_fb689_row14_col1, #T_fb689_row15_col1, #T_fb689_row16_col1 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_fb689_row17_col1, #T_fb689_row18_col1, #T_fb689_row19_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_fb689">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fb689_level0_col0" class="col_heading level0 col0" >Common_words</th>
#       <th id="T_fb689_level0_col1" class="col_heading level0 col1" >count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fb689_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fb689_row0_col0" class="data row0 col0" >new</td>
#       <td id="T_fb689_row0_col1" class="data row0 col1" >43</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fb689_row1_col0" class="data row1 col0" >joy</td>
#       <td id="T_fb689_row1_col1" class="data row1 col1" >39</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_fb689_row2_col0" class="data row2 col0" >life</td>
#       <td id="T_fb689_row2_col1" class="data row2 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_fb689_row3_col0" class="data row3 col0" >challeng</td>
#       <td id="T_fb689_row3_col1" class="data row3 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_fb689_row4_col0" class="data row4 col0" >hope</td>
#       <td id="T_fb689_row4_col1" class="data row4 col1" >37</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_fb689_row5_col0" class="data row5 col0" >seren</td>
#       <td id="T_fb689_row5_col1" class="data row5 col1" >36</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_fb689_row6_col0" class="data row6 col0" >excit</td>
#       <td id="T_fb689_row6_col1" class="data row6 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_fb689_row7_col0" class="data row7 col0" >danc</td>
#       <td id="T_fb689_row7_col1" class="data row7 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_fb689_row8_col0" class="data row8 col0" >day</td>
#       <td id="T_fb689_row8_col1" class="data row8 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_fb689_row9_col0" class="data row9 col0" >feel</td>
#       <td id="T_fb689_row9_col1" class="data row9 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_fb689_row10_col0" class="data row10 col0" >emot</td>
#       <td id="T_fb689_row10_col1" class="data row10 col1" >29</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_fb689_row11_col0" class="data row11 col0" >like</td>
#       <td id="T_fb689_row11_col1" class="data row11 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_fb689_row12_col0" class="data row12 col0" >dream</td>
#       <td id="T_fb689_row12_col1" class="data row12 col1" >28</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_fb689_row13_col0" class="data row13 col0" >explor</td>
#       <td id="T_fb689_row13_col1" class="data row13 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_fb689_row14_col0" class="data row14 col0" >friend</td>
#       <td id="T_fb689_row14_col1" class="data row14 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_fb689_row15_col0" class="data row15 col0" >inspir</td>
#       <td id="T_fb689_row15_col1" class="data row15 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_fb689_row16_col0" class="data row16 col0" >moment</td>
#       <td id="T_fb689_row16_col1" class="data row16 col1" >27</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_fb689_row17_col0" class="data row17 col0" >gratitud</td>
#       <td id="T_fb689_row17_col1" class="data row17 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_fb689_row18_col0" class="data row18 col0" >love</td>
#       <td id="T_fb689_row18_col1" class="data row18 col1" >26</td>
#     </tr>
#     <tr>
#       <th id="T_fb689_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_fb689_row19_col0" class="data row19 col0" >heart</td>
#       <td id="T_fb689_row19_col1" class="data row19 col1" >26</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Function to process text and return most common positve words
top = Counter([item for sublist in df[df['Sentiment'] == 'Positive']['common_word_list'] for item in sublist])
positive = pd.DataFrame(top.most_common(10), columns=['Common_Words', 'Count'])
positive.style.background_gradient(cmap='Greens')
# Out:
# <style type="text/css">
# #T_538d2_row0_col1 {
#   background-color: #00441b;
#   color: #f1f1f1;
# }
# #T_538d2_row1_col1 {
#   background-color: #228a44;
#   color: #f1f1f1;
# }
# #T_538d2_row2_col1 {
#   background-color: #a9dca3;
#   color: #000000;
# }
# #T_538d2_row3_col1, #T_538d2_row4_col1 {
#   background-color: #b8e3b2;
#   color: #000000;
# }
# #T_538d2_row5_col1, #T_538d2_row6_col1 {
#   background-color: #dff3da;
#   color: #000000;
# }
# #T_538d2_row7_col1, #T_538d2_row8_col1 {
#   background-color: #e9f7e5;
#   color: #000000;
# }
# #T_538d2_row9_col1 {
#   background-color: #f7fcf5;
#   color: #000000;
# }
# </style>
# <table id="T_538d2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_538d2_level0_col0" class="col_heading level0 col0" >Common_Words</th>
#       <th id="T_538d2_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_538d2_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_538d2_row0_col0" class="data row0 col0" >joy</td>
#       <td id="T_538d2_row0_col1" class="data row0 col1" >38</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_538d2_row1_col0" class="data row1 col0" >hope</td>
#       <td id="T_538d2_row1_col1" class="data row1 col1" >33</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_538d2_row2_col0" class="data row2 col0" >friend</td>
#       <td id="T_538d2_row2_col1" class="data row2 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_538d2_row3_col0" class="data row3 col0" >laughter</td>
#       <td id="T_538d2_row3_col1" class="data row3 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_538d2_row4_col0" class="data row4 col0" >gratitud</td>
#       <td id="T_538d2_row4_col1" class="data row4 col1" >24</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_538d2_row5_col0" class="data row5 col0" >new</td>
#       <td id="T_538d2_row5_col1" class="data row5 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_538d2_row6_col0" class="data row6 col0" >challeng</td>
#       <td id="T_538d2_row6_col1" class="data row6 col1" >21</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_538d2_row7_col0" class="data row7 col0" >love</td>
#       <td id="T_538d2_row7_col1" class="data row7 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_538d2_row8_col0" class="data row8 col0" >dream</td>
#       <td id="T_538d2_row8_col1" class="data row8 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_538d2_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_538d2_row9_col0" class="data row9 col0" >success</td>
#       <td id="T_538d2_row9_col1" class="data row9 col1" >18</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Function to process text and return most common neutral words
top = Counter([item for sublist in df[df['Sentiment'] == 'Neutral']['common_word_list'] for item in sublist])
neutral = pd.DataFrame(top.most_common(10), columns=['Common_Words', 'Count'])
neutral.style.background_gradient(cmap='gray')
# Out:
# <style type="text/css">
# #T_ae0f1_row0_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_ae0f1_row1_col1 {
#   background-color: #c0c0c0;
#   color: #000000;
# }
# #T_ae0f1_row2_col1 {
#   background-color: #959595;
#   color: #f1f1f1;
# }
# #T_ae0f1_row3_col1 {
#   background-color: #2a2a2a;
#   color: #f1f1f1;
# }
# #T_ae0f1_row4_col1, #T_ae0f1_row5_col1, #T_ae0f1_row6_col1 {
#   background-color: #151515;
#   color: #f1f1f1;
# }
# #T_ae0f1_row7_col1, #T_ae0f1_row8_col1, #T_ae0f1_row9_col1 {
#   background-color: #000000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_ae0f1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae0f1_level0_col0" class="col_heading level0 col0" >Common_Words</th>
#       <th id="T_ae0f1_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae0f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae0f1_row0_col0" class="data row0 col0" >seren</td>
#       <td id="T_ae0f1_row0_col1" class="data row0 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ae0f1_row1_col0" class="data row1 col0" >new</td>
#       <td id="T_ae0f1_row1_col1" class="data row1 col1" >22</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ae0f1_row2_col0" class="data row2 col0" >excit</td>
#       <td id="T_ae0f1_row2_col1" class="data row2 col1" >20</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ae0f1_row3_col0" class="data row3 col0" >explor</td>
#       <td id="T_ae0f1_row3_col1" class="data row3 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ae0f1_row4_col0" class="data row4 col0" >life</td>
#       <td id="T_ae0f1_row4_col1" class="data row4 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ae0f1_row5_col0" class="data row5 col0" >loneli</td>
#       <td id="T_ae0f1_row5_col1" class="data row5 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ae0f1_row6_col0" class="data row6 col0" >danc</td>
#       <td id="T_ae0f1_row6_col1" class="data row6 col1" >14</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ae0f1_row7_col0" class="data row7 col0" >inspir</td>
#       <td id="T_ae0f1_row7_col1" class="data row7 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ae0f1_row8_col0" class="data row8 col0" >beauti</td>
#       <td id="T_ae0f1_row8_col1" class="data row8 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ae0f1_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ae0f1_row9_col0" class="data row9 col0" >confus</td>
#       <td id="T_ae0f1_row9_col1" class="data row9 col1" >13</td>
#     </tr>
#   </tbody>
# </table>

# %%
# Function to process text and return most common negative words
top = Counter([item for sublist in df[df['Sentiment'] == 'Negative']['common_word_list'] for item in sublist])
negative = pd.DataFrame(top.most_common(10), columns=['Common_Words', 'Count'])
negative.style.background_gradient(cmap='Reds')
# Out:
# <style type="text/css">
# #T_47c58_row0_col1 {
#   background-color: #67000d;
#   color: #f1f1f1;
# }
# #T_47c58_row1_col1, #T_47c58_row2_col1 {
#   background-color: #fc9879;
#   color: #000000;
# }
# #T_47c58_row3_col1, #T_47c58_row4_col1, #T_47c58_row5_col1 {
#   background-color: #fedbcc;
#   color: #000000;
# }
# #T_47c58_row6_col1, #T_47c58_row7_col1, #T_47c58_row8_col1 {
#   background-color: #fee9df;
#   color: #000000;
# }
# #T_47c58_row9_col1 {
#   background-color: #fff5f0;
#   color: #000000;
# }
# </style>
# <table id="T_47c58">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_47c58_level0_col0" class="col_heading level0 col0" >Common_Words</th>
#       <th id="T_47c58_level0_col1" class="col_heading level0 col1" >Count</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47c58_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47c58_row0_col0" class="data row0 col0" >despair</td>
#       <td id="T_47c58_row0_col1" class="data row0 col1" >25</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_47c58_row1_col0" class="data row1 col0" >bitter</td>
#       <td id="T_47c58_row1_col1" class="data row1 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_47c58_row2_col0" class="data row2 col0" >grief</td>
#       <td id="T_47c58_row2_col1" class="data row2 col1" >16</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_47c58_row3_col0" class="data row3 col0" >emot</td>
#       <td id="T_47c58_row3_col1" class="data row3 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_47c58_row4_col0" class="data row4 col0" >lost</td>
#       <td id="T_47c58_row4_col1" class="data row4 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_47c58_row5_col0" class="data row5 col0" >numb</td>
#       <td id="T_47c58_row5_col1" class="data row5 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_47c58_row6_col0" class="data row6 col0" >feel</td>
#       <td id="T_47c58_row6_col1" class="data row6 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_47c58_row7_col0" class="data row7 col0" >fear</td>
#       <td id="T_47c58_row7_col1" class="data row7 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_47c58_row8_col0" class="data row8 col0" >betray</td>
#       <td id="T_47c58_row8_col1" class="data row8 col1" >12</td>
#     </tr>
#     <tr>
#       <th id="T_47c58_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_47c58_row9_col0" class="data row9 col0" >overwhelm</td>
#       <td id="T_47c58_row9_col1" class="data row9 col1" >11</td>
#     </tr>
#   </tbody>
# </table>
